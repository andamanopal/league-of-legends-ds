# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from riotwatcher import LolWatcher, ApiError
import time

# %% [markdown]
# ### Related Doc.
#
# - https://hextechdocs.dev/crawling-matches-using-the-riot-games-api/
# - https://towardsdatascience.com/how-to-use-riot-api-with-python-b93be82dbbd6

# %%
api_key = 'RGAPI-d1d56f1a-022d-4ce6-a6dd-e4a4f43ce225'

watcher = LolWatcher(api_key)
my_region = 'na1'

me = watcher.summoner.by_name(my_region, 'LL Stylish')
print(me)

# Return the rank status for Doublelift
my_ranked_stats = watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)
# Out:
# {'id': '5HAJ0hfWvrrquSAVwaWgRdlTCe8kmsV0Ker6UiNrFH59UQM', 'accountId': 'Z_s396xDAozKjjn5uu-Zo5lK15AS_3hyn4HUZ0aG47ce5GE', 'puuid': 'Mj97ukUjMXvsgpVdqJ189fzkIgf9hPAqZQ3YAdYkLTBjhBynkNkgceLYMoL4WpyFT4cUmMbpUU1VYw', 'name': 'LL Stylish', 'profileIconId': 5127, 'revisionDate': 1643252180000, 'summonerLevel': 220}
# [{'leagueId': 'ca2c0b26-447a-45b0-a5f6-b6eb2f3be95c', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'DIAMOND', 'rank': 'I', 'summonerId': '5HAJ0hfWvrrquSAVwaWgRdlTCe8kmsV0Ker6UiNrFH59UQM', 'summonerName': 'LL Stylish', 'leaguePoints': 21, 'wins': 22, 'losses': 28, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}]

# %% [markdown]
# ## Get List of Challenger Players

# %%
# Get all challenger players in na ranked

na_cha = watcher.league.challenger_by_queue('na1', 'RANKED_SOLO_5x5')

players_count = len(na_cha['entries'])
player_id = []
player_name = []
player_puuid = []

for index, player in enumerate(na_cha['entries']):
    player_id.append(player['summonerId'])
    player_name.append(player['summonerName'])
    player_puuid.append(watcher.summoner.by_id('na1', player['summonerId'])['puuid'])
    if index % 20 == 19 :
        print(f'Progress: {index}/{players_count}')
        break
# Out:
# Progress: 19/223

# %% [markdown]
# ## Collect Matche_IDs in Challenger Division

# %%
# Get all non-duplicated matches

chal_matches_ids = set()

for index, puuid in enumerate(player_puuid):
    chal_matches_ids.update(watcher.match.matchlist_by_puuid('americas'
                                                            ,puuid=puuid
                                                            ,count=100)
                          )
    if index%5==0: print(f'Progress : {index+1}/{len(player_puuid)}')
        
print(f'Number of matches : {len(chal_matches_ids)}')
# Out:
# Progress : 1/20
# Progress : 6/20
# Progress : 11/20
# Progress : 16/20
# Number of matches : 1811

# %% [markdown]
# ## Get Each Match Information (including all players stats)

# %%
# Get all matches info

matches=[]

for index, match_id in enumerate(chal_matches_ids):
    matches.append(watcher.match.by_id('americas', match_id))
    if index%50==0: print(f'Progress : {index+1}/{len(chal_matches_ids)}')
    if index == 100: break
# Out:
# Progress : 1/1811
# Progress : 51/1811
# Progress : 101/1811

# %% [markdown]
# ## Save Matches/Players Stats to .csv

# %%
# Save matches data of each player in .csv file

df = pd.DataFrame()

for match in matches:
    game_version = match['info']['gameVersion']
    game_mode = match['info']['gameMode']
    game_duration = match['info']['gameDuration']
    
    if game_mode == 'CLASSIC':
        participants = pd.DataFrame(match['info']['participants'])
        participants.insert(0, 'matchId', match['metadata']['matchId'])
        participants['game_version'] = game_version
        participants['game_duration'] = game_duration
        df = df.append(pd.DataFrame(participants))

front_columns = ['matchId', 'summonerId', 'championName', 'teamId', 'teamPosition', 'kills', 'assists', 'deaths', 'goldEarned']
columns_ordered = front_columns + df.columns.drop(front_columns).to_list()
df = df.reindex(columns=columns_ordered)

df.to_csv('matches_data.csv', index=False)

# %% [markdown]
# ## Get Match Timeline Data

# %%
# Get win/lose data of blue_team (teamId == 100) of each match id in .csv
# Select only matches with duration more than 15 minutes

df = pd.read_csv('matches_data.csv')
blue_wins = df.loc[(df['teamId']==100) & (df['game_duration'] >= 900)].pivot_table(values=['teamId', 'win'], index=['matchId'])
display(blue_wins.head())
print(blue_wins.shape)
# Out:
#                 teamId    win
# matchId
# NA1_4134639110     100  False
# NA1_4135794736     100  False
# NA1_4136156707     100  False
# NA1_4136537752     100   True
# NA1_4137045009     100   True
# (6081, 2)

# %%
matches_timeline = []
start = time.time()

for index, match_id in enumerate(blue_wins.index):
    matches_timeline.append(watcher.match.timeline_by_match(region='americas', match_id=match_id))
    
    if index%10==0:
        now = time.time()
        if index == 0:
            time_10_matchs = now - start
        else:
            time_10_matchs = now - prev
        prev = now
        print(f'Progress : {index}/{len(blue_wins.index)} Estimated Time Left : {(len(blue_wins.index)-index)/600*time_10_matchs:.2f} min(s)')
# Out:
# Progress : 0/6081 Estimated Time Left : 1055.98 min(s)
# Progress : 10/6081 Estimated Time Left : 59.21 min(s)
# Progress : 20/6081 Estimated Time Left : 55.41 min(s)
# Progress : 30/6081 Estimated Time Left : 51.94 min(s)
# Progress : 40/6081 Estimated Time Left : 57.49 min(s)
# Progress : 50/6081 Estimated Time Left : 58.97 min(s)
# Progress : 60/6081 Estimated Time Left : 61.67 min(s)
# Progress : 70/6081 Estimated Time Left : 62.30 min(s)
# Progress : 80/6081 Estimated Time Left : 53.47 min(s)
# Progress : 90/6081 Estimated Time Left : 55.21 min(s)
# Progress : 100/6081 Estimated Time Left : 706.96 min(s)
# Progress : 110/6081 Estimated Time Left : 62.46 min(s)
# Progress : 120/6081 Estimated Time Left : 54.66 min(s)
# Progress : 130/6081 Estimated Time Left : 49.11 min(s)
# Progress : 140/6081 Estimated Time Left : 49.75 min(s)
# Progress : 150/6081 Estimated Time Left : 59.69 min(s)
# Progress : 160/6081 Estimated Time Left : 54.74 min(s)
# Progress : 170/6081 Estimated Time Left : 57.26 min(s)
# Progress : 180/6081 Estimated Time Left : 51.44 min(s)
# Progress : 190/6081 Estimated Time Left : 53.56 min(s)
# Progress : 200/6081 Estimated Time Left : 704.94 min(s)
# Progress : 210/6081 Estimated Time Left : 50.26 min(s)
# Progress : 220/6081 Estimated Time Left : 56.68 min(s)
# Progress : 230/6081 Estimated Time Left : 50.04 min(s)
# Progress : 240/6081 Estimated Time Left : 55.27 min(s)
# Progress : 250/6081 Estimated Time Left : 62.25 min(s)
# Progress : 260/6081 Estimated Time Left : 52.06 min(s)
# Progress : 270/6081 Estimated Time Left : 47.84 min(s)
# Progress : 280/6081 Estimated Time Left : 60.14 min(s)
# Progress : 290/6081 Estimated Time Left : 60.54 min(s)
# Progress : 300/6081 Estimated Time Left : 683.80 min(s)
# Progress : 310/6081 Estimated Time Left : 54.07 min(s)
# Progress : 320/6081 Estimated Time Left : 51.56 min(s)
# Progress : 330/6081 Estimated Time Left : 52.30 min(s)
# Progress : 340/6081 Estimated Time Left : 58.27 min(s)
# Progress : 350/6081 Estimated Time Left : 54.56 min(s)
# Progress : 360/6081 Estimated Time Left : 50.45 min(s)
# Progress : 370/6081 Estimated Time Left : 51.83 min(s)
# Progress : 380/6081 Estimated Time Left : 62.93 min(s)
# Progress : 390/6081 Estimated Time Left : 49.09 min(s)
# Progress : 400/6081 Estimated Time Left : 672.21 min(s)
# Progress : 410/6081 Estimated Time Left : 50.63 min(s)
# Progress : 420/6081 Estimated Time Left : 58.93 min(s)
# Progress : 430/6081 Estimated Time Left : 63.24 min(s)
# Progress : 440/6081 Estimated Time Left : 52.94 min(s)
# Progress : 450/6081 Estimated Time Left : 57.70 min(s)
# Progress : 460/6081 Estimated Time Left : 55.46 min(s)
# Progress : 470/6081 Estimated Time Left : 51.67 min(s)
# Progress : 480/6081 Estimated Time Left : 52.42 min(s)
# Progress : 490/6081 Estimated Time Left : 56.87 min(s)
# Progress : 500/6081 Estimated Time Left : 637.62 min(s)
# Progress : 510/6081 Estimated Time Left : 48.45 min(s)
# Progress : 520/6081 Estimated Time Left : 49.93 min(s)
# Progress : 530/6081 Estimated Time Left : 53.70 min(s)
# Progress : 540/6081 Estimated Time Left : 55.82 min(s)
# Progress : 550/6081 Estimated Time Left : 56.07 min(s)
# Progress : 560/6081 Estimated Time Left : 55.56 min(s)
# Progress : 570/6081 Estimated Time Left : 51.80 min(s)
# Progress : 580/6081 Estimated Time Left : 50.95 min(s)
# Progress : 590/6081 Estimated Time Left : 52.84 min(s)
# Progress : 600/6081 Estimated Time Left : 641.15 min(s)
# Progress : 610/6081 Estimated Time Left : 46.51 min(s)
# Progress : 620/6081 Estimated Time Left : 48.17 min(s)
# Progress : 630/6081 Estimated Time Left : 47.52 min(s)
# Progress : 640/6081 Estimated Time Left : 48.20 min(s)
# Progress : 650/6081 Estimated Time Left : 52.15 min(s)
# Progress : 660/6081 Estimated Time Left : 46.12 min(s)
# Progress : 670/6081 Estimated Time Left : 50.03 min(s)
# Progress : 680/6081 Estimated Time Left : 50.25 min(s)
# Progress : 690/6081 Estimated Time Left : 51.54 min(s)
# Progress : 700/6081 Estimated Time Left : 655.61 min(s)
# Progress : 710/6081 Estimated Time Left : 58.16 min(s)
# Progress : 720/6081 Estimated Time Left : 47.71 min(s)
# Progress : 730/6081 Estimated Time Left : 58.69 min(s)
# Progress : 740/6081 Estimated Time Left : 47.60 min(s)
# Progress : 750/6081 Estimated Time Left : 51.34 min(s)
# Progress : 760/6081 Estimated Time Left : 46.29 min(s)
# Progress : 770/6081 Estimated Time Left : 48.39 min(s)
# Progress : 780/6081 Estimated Time Left : 54.08 min(s)
# Progress : 790/6081 Estimated Time Left : 55.47 min(s)
# Progress : 800/6081 Estimated Time Left : 609.86 min(s)
# Progress : 810/6081 Estimated Time Left : 46.83 min(s)
# Progress : 820/6081 Estimated Time Left : 49.66 min(s)
# Progress : 830/6081 Estimated Time Left : 58.76 min(s)
# Progress : 840/6081 Estimated Time Left : 44.31 min(s)
# Progress : 850/6081 Estimated Time Left : 45.11 min(s)
# Progress : 860/6081 Estimated Time Left : 55.38 min(s)
# Progress : 870/6081 Estimated Time Left : 45.86 min(s)
# Progress : 880/6081 Estimated Time Left : 55.02 min(s)
# Progress : 890/6081 Estimated Time Left : 49.66 min(s)
# Progress : 900/6081 Estimated Time Left : 605.10 min(s)
# Progress : 910/6081 Estimated Time Left : 50.24 min(s)
# Progress : 920/6081 Estimated Time Left : 61.18 min(s)
# Progress : 930/6081 Estimated Time Left : 48.93 min(s)
# Progress : 940/6081 Estimated Time Left : 50.86 min(s)
# Progress : 950/6081 Estimated Time Left : 50.28 min(s)
# Progress : 960/6081 Estimated Time Left : 46.56 min(s)
# Progress : 970/6081 Estimated Time Left : 43.76 min(s)
# Progress : 980/6081 Estimated Time Left : 48.98 min(s)
# Progress : 990/6081 Estimated Time Left : 44.92 min(s)
# Progress : 1000/6081 Estimated Time Left : 587.63 min(s)
# Progress : 1010/6081 Estimated Time Left : 58.61 min(s)
# Progress : 1020/6081 Estimated Time Left : 48.57 min(s)
# Progress : 1030/6081 Estimated Time Left : 49.79 min(s)
# Progress : 1040/6081 Estimated Time Left : 44.96 min(s)
# Progress : 1050/6081 Estimated Time Left : 43.71 min(s)
# Progress : 1060/6081 Estimated Time Left : 41.38 min(s)
# Progress : 1070/6081 Estimated Time Left : 54.27 min(s)
# Progress : 1080/6081 Estimated Time Left : 45.89 min(s)
# Progress : 1090/6081 Estimated Time Left : 48.05 min(s)
# Progress : 1100/6081 Estimated Time Left : 581.88 min(s)
# Progress : 1110/6081 Estimated Time Left : 45.19 min(s)
# Progress : 1120/6081 Estimated Time Left : 49.27 min(s)
# Progress : 1130/6081 Estimated Time Left : 46.43 min(s)
# Progress : 1140/6081 Estimated Time Left : 42.46 min(s)
# Progress : 1150/6081 Estimated Time Left : 46.27 min(s)
# Progress : 1160/6081 Estimated Time Left : 44.65 min(s)
# Progress : 1170/6081 Estimated Time Left : 41.79 min(s)
# Progress : 1180/6081 Estimated Time Left : 41.20 min(s)
# Progress : 1190/6081 Estimated Time Left : 48.91 min(s)
# Progress : 1200/6081 Estimated Time Left : 588.18 min(s)
# Progress : 1210/6081 Estimated Time Left : 46.13 min(s)
# Progress : 1220/6081 Estimated Time Left : 45.67 min(s)
# Progress : 1230/6081 Estimated Time Left : 47.89 min(s)
# Progress : 1240/6081 Estimated Time Left : 52.54 min(s)
# Progress : 1250/6081 Estimated Time Left : 45.77 min(s)
# Progress : 1260/6081 Estimated Time Left : 40.70 min(s)
# Progress : 1270/6081 Estimated Time Left : 52.95 min(s)
# Progress : 1280/6081 Estimated Time Left : 48.48 min(s)
# Progress : 1290/6081 Estimated Time Left : 45.16 min(s)
# Progress : 1300/6081 Estimated Time Left : 549.52 min(s)
# Progress : 1310/6081 Estimated Time Left : 49.14 min(s)
# Progress : 1320/6081 Estimated Time Left : 47.53 min(s)
# Progress : 1330/6081 Estimated Time Left : 45.89 min(s)
# Progress : 1340/6081 Estimated Time Left : 46.51 min(s)
# Progress : 1350/6081 Estimated Time Left : 50.23 min(s)
# Progress : 1360/6081 Estimated Time Left : 45.01 min(s)
# Progress : 1370/6081 Estimated Time Left : 42.17 min(s)
# Progress : 1380/6081 Estimated Time Left : 48.97 min(s)
# Progress : 1390/6081 Estimated Time Left : 43.16 min(s)
# Progress : 1400/6081 Estimated Time Left : 535.45 min(s)
# Progress : 1410/6081 Estimated Time Left : 45.30 min(s)
# Progress : 1420/6081 Estimated Time Left : 45.73 min(s)
# Progress : 1430/6081 Estimated Time Left : 43.94 min(s)
# Progress : 1440/6081 Estimated Time Left : 40.44 min(s)
# Progress : 1450/6081 Estimated Time Left : 42.70 min(s)
# Progress : 1460/6081 Estimated Time Left : 38.59 min(s)
# Progress : 1470/6081 Estimated Time Left : 41.71 min(s)
# Progress : 1480/6081 Estimated Time Left : 38.11 min(s)
# Progress : 1490/6081 Estimated Time Left : 40.56 min(s)
# Progress : 1500/6081 Estimated Time Left : 556.62 min(s)
# Progress : 1510/6081 Estimated Time Left : 38.22 min(s)
# Progress : 1520/6081 Estimated Time Left : 43.89 min(s)
# Progress : 1530/6081 Estimated Time Left : 48.10 min(s)
# Progress : 1540/6081 Estimated Time Left : 39.70 min(s)
# Progress : 1550/6081 Estimated Time Left : 40.77 min(s)
# Progress : 1560/6081 Estimated Time Left : 41.07 min(s)
# Progress : 1570/6081 Estimated Time Left : 42.65 min(s)
# Progress : 1580/6081 Estimated Time Left : 48.32 min(s)
# Progress : 1590/6081 Estimated Time Left : 36.38 min(s)
# Progress : 1600/6081 Estimated Time Left : 534.40 min(s)
# Progress : 1610/6081 Estimated Time Left : 40.86 min(s)
# Progress : 1620/6081 Estimated Time Left : 43.83 min(s)
# Progress : 1630/6081 Estimated Time Left : 42.58 min(s)
# Progress : 1640/6081 Estimated Time Left : 45.07 min(s)
# Progress : 1650/6081 Estimated Time Left : 44.39 min(s)
# Progress : 1660/6081 Estimated Time Left : 38.87 min(s)
# Progress : 1670/6081 Estimated Time Left : 53.21 min(s)
# Progress : 1680/6081 Estimated Time Left : 38.51 min(s)
# Progress : 1690/6081 Estimated Time Left : 39.61 min(s)
# Progress : 1700/6081 Estimated Time Left : 506.12 min(s)
# Progress : 1710/6081 Estimated Time Left : 39.06 min(s)
# Progress : 1720/6081 Estimated Time Left : 36.09 min(s)
# Progress : 1730/6081 Estimated Time Left : 37.64 min(s)
# Progress : 1740/6081 Estimated Time Left : 36.24 min(s)
# Progress : 1750/6081 Estimated Time Left : 41.78 min(s)
# Progress : 1760/6081 Estimated Time Left : 38.01 min(s)
# Progress : 1770/6081 Estimated Time Left : 39.15 min(s)
# Progress : 1780/6081 Estimated Time Left : 50.83 min(s)
# Progress : 1790/6081 Estimated Time Left : 36.28 min(s)
# Progress : 1800/6081 Estimated Time Left : 518.04 min(s)
# Progress : 1810/6081 Estimated Time Left : 40.41 min(s)
# Progress : 1820/6081 Estimated Time Left : 42.10 min(s)
# Progress : 1830/6081 Estimated Time Left : 45.96 min(s)
# Progress : 1840/6081 Estimated Time Left : 39.33 min(s)
# Progress : 1850/6081 Estimated Time Left : 35.21 min(s)
# Progress : 1860/6081 Estimated Time Left : 43.82 min(s)
# Progress : 1870/6081 Estimated Time Left : 36.73 min(s)
# Progress : 1880/6081 Estimated Time Left : 39.10 min(s)
# Progress : 1890/6081 Estimated Time Left : 42.78 min(s)
# Progress : 1900/6081 Estimated Time Left : 485.52 min(s)
# Progress : 1910/6081 Estimated Time Left : 38.05 min(s)
# Progress : 1920/6081 Estimated Time Left : 40.76 min(s)
# Progress : 1930/6081 Estimated Time Left : 35.72 min(s)
# Progress : 1940/6081 Estimated Time Left : 37.69 min(s)
# Progress : 1950/6081 Estimated Time Left : 40.89 min(s)
# Progress : 1960/6081 Estimated Time Left : 40.75 min(s)
# Progress : 1970/6081 Estimated Time Left : 37.62 min(s)
# Progress : 1980/6081 Estimated Time Left : 38.78 min(s)
# Progress : 1990/6081 Estimated Time Left : 41.13 min(s)
# Progress : 2000/6081 Estimated Time Left : 483.96 min(s)
# Progress : 2010/6081 Estimated Time Left : 59.23 min(s)
# Progress : 2020/6081 Estimated Time Left : 52.41 min(s)
# Progress : 2030/6081 Estimated Time Left : 54.46 min(s)
# Progress : 2040/6081 Estimated Time Left : 54.06 min(s)
# Progress : 2050/6081 Estimated Time Left : 52.85 min(s)
# Progress : 2060/6081 Estimated Time Left : 45.68 min(s)
# Progress : 2070/6081 Estimated Time Left : 44.31 min(s)
# Progress : 2080/6081 Estimated Time Left : 47.15 min(s)
# Progress : 2090/6081 Estimated Time Left : 45.34 min(s)
# Progress : 2100/6081 Estimated Time Left : 358.59 min(s)
# Progress : 2110/6081 Estimated Time Left : 35.66 min(s)
# Progress : 2120/6081 Estimated Time Left : 38.70 min(s)
# Progress : 2130/6081 Estimated Time Left : 33.54 min(s)
# Progress : 2140/6081 Estimated Time Left : 36.04 min(s)
# Progress : 2150/6081 Estimated Time Left : 40.12 min(s)
# Progress : 2160/6081 Estimated Time Left : 34.05 min(s)
# Progress : 2170/6081 Estimated Time Left : 34.75 min(s)
# Progress : 2180/6081 Estimated Time Left : 35.66 min(s)
# Progress : 2190/6081 Estimated Time Left : 35.30 min(s)
# Progress : 2200/6081 Estimated Time Left : 467.47 min(s)
# Progress : 2210/6081 Estimated Time Left : 36.27 min(s)
# Progress : 2220/6081 Estimated Time Left : 38.48 min(s)
# Progress : 2230/6081 Estimated Time Left : 37.72 min(s)
# Progress : 2240/6081 Estimated Time Left : 38.21 min(s)
# Progress : 2250/6081 Estimated Time Left : 36.56 min(s)
# Progress : 2260/6081 Estimated Time Left : 39.78 min(s)
# Progress : 2270/6081 Estimated Time Left : 43.96 min(s)
# Progress : 2280/6081 Estimated Time Left : 32.36 min(s)
# Progress : 2290/6081 Estimated Time Left : 36.48 min(s)
# Progress : 2300/6081 Estimated Time Left : 431.76 min(s)
# Progress : 2310/6081 Estimated Time Left : 31.72 min(s)
# Progress : 2320/6081 Estimated Time Left : 38.02 min(s)
# Progress : 2330/6081 Estimated Time Left : 34.37 min(s)
# Progress : 2340/6081 Estimated Time Left : 34.57 min(s)
# Progress : 2350/6081 Estimated Time Left : 42.86 min(s)
# Progress : 2360/6081 Estimated Time Left : 35.23 min(s)
# Progress : 2370/6081 Estimated Time Left : 32.54 min(s)
# Progress : 2380/6081 Estimated Time Left : 37.91 min(s)
# Progress : 2390/6081 Estimated Time Left : 29.62 min(s)
# Progress : 2400/6081 Estimated Time Left : 434.09 min(s)
# Progress : 2410/6081 Estimated Time Left : 34.17 min(s)
# Progress : 2420/6081 Estimated Time Left : 35.54 min(s)
# Progress : 2430/6081 Estimated Time Left : 33.37 min(s)
# Progress : 2440/6081 Estimated Time Left : 37.11 min(s)
# Progress : 2450/6081 Estimated Time Left : 30.97 min(s)
# Progress : 2460/6081 Estimated Time Left : 33.89 min(s)
# Progress : 2470/6081 Estimated Time Left : 34.85 min(s)
# Progress : 2480/6081 Estimated Time Left : 29.15 min(s)
# Progress : 2490/6081 Estimated Time Left : 35.61 min(s)
# Progress : 2500/6081 Estimated Time Left : 428.95 min(s)
# Progress : 2510/6081 Estimated Time Left : 35.86 min(s)
# Progress : 2520/6081 Estimated Time Left : 34.57 min(s)
# Progress : 2530/6081 Estimated Time Left : 33.09 min(s)
# Progress : 2540/6081 Estimated Time Left : 31.68 min(s)
# Progress : 2550/6081 Estimated Time Left : 33.46 min(s)
# Progress : 2560/6081 Estimated Time Left : 32.80 min(s)
# Progress : 2570/6081 Estimated Time Left : 31.62 min(s)
# Progress : 2580/6081 Estimated Time Left : 37.79 min(s)
# Progress : 2590/6081 Estimated Time Left : 36.76 min(s)
# Progress : 2600/6081 Estimated Time Left : 403.48 min(s)
# Progress : 2610/6081 Estimated Time Left : 35.77 min(s)
# Progress : 2620/6081 Estimated Time Left : 35.42 min(s)
# Progress : 2630/6081 Estimated Time Left : 29.74 min(s)
# Progress : 2640/6081 Estimated Time Left : 33.86 min(s)
# Progress : 2650/6081 Estimated Time Left : 30.53 min(s)
# Progress : 2660/6081 Estimated Time Left : 34.87 min(s)
# Progress : 2670/6081 Estimated Time Left : 29.83 min(s)
# Progress : 2680/6081 Estimated Time Left : 33.48 min(s)
# Progress : 2690/6081 Estimated Time Left : 29.80 min(s)
# Progress : 2700/6081 Estimated Time Left : 397.54 min(s)
# Progress : 2710/6081 Estimated Time Left : 46.49 min(s)
# Progress : 2720/6081 Estimated Time Left : 46.20 min(s)
# Progress : 2730/6081 Estimated Time Left : 41.89 min(s)
# Progress : 2740/6081 Estimated Time Left : 35.45 min(s)
# Progress : 2750/6081 Estimated Time Left : 36.92 min(s)
# Progress : 2760/6081 Estimated Time Left : 37.39 min(s)
# Progress : 2770/6081 Estimated Time Left : 37.73 min(s)
# Progress : 2780/6081 Estimated Time Left : 44.42 min(s)
# Progress : 2790/6081 Estimated Time Left : 37.23 min(s)
# Progress : 2800/6081 Estimated Time Left : 307.85 min(s)
# Progress : 2810/6081 Estimated Time Left : 32.50 min(s)
# Progress : 2820/6081 Estimated Time Left : 29.01 min(s)
# Progress : 2830/6081 Estimated Time Left : 34.60 min(s)
# Progress : 2840/6081 Estimated Time Left : 29.29 min(s)
# Progress : 2850/6081 Estimated Time Left : 28.78 min(s)
# Progress : 2860/6081 Estimated Time Left : 30.02 min(s)
# Progress : 2870/6081 Estimated Time Left : 36.49 min(s)
# Progress : 2880/6081 Estimated Time Left : 32.13 min(s)
# Progress : 2890/6081 Estimated Time Left : 29.76 min(s)
# Progress : 2900/6081 Estimated Time Left : 365.69 min(s)
# Progress : 2910/6081 Estimated Time Left : 32.86 min(s)
# Progress : 2920/6081 Estimated Time Left : 27.48 min(s)
# Progress : 2930/6081 Estimated Time Left : 33.71 min(s)
# Progress : 2940/6081 Estimated Time Left : 31.39 min(s)
# Progress : 2950/6081 Estimated Time Left : 32.87 min(s)
# Progress : 2960/6081 Estimated Time Left : 28.82 min(s)
# Progress : 2970/6081 Estimated Time Left : 31.64 min(s)
# Progress : 2980/6081 Estimated Time Left : 35.06 min(s)
# Progress : 2990/6081 Estimated Time Left : 29.11 min(s)
# Progress : 3000/6081 Estimated Time Left : 346.61 min(s)
# Progress : 3010/6081 Estimated Time Left : 34.26 min(s)
# Progress : 3020/6081 Estimated Time Left : 31.35 min(s)
# Progress : 3030/6081 Estimated Time Left : 30.89 min(s)
# Progress : 3040/6081 Estimated Time Left : 32.89 min(s)
# Progress : 3050/6081 Estimated Time Left : 28.17 min(s)
# Progress : 3060/6081 Estimated Time Left : 32.59 min(s)
# Progress : 3070/6081 Estimated Time Left : 34.06 min(s)
# Progress : 3080/6081 Estimated Time Left : 33.23 min(s)
# Progress : 3090/6081 Estimated Time Left : 33.04 min(s)
# Progress : 3100/6081 Estimated Time Left : 319.14 min(s)
# Progress : 3110/6081 Estimated Time Left : 29.24 min(s)
# Progress : 3120/6081 Estimated Time Left : 27.29 min(s)
# Progress : 3130/6081 Estimated Time Left : 27.89 min(s)
# Progress : 3140/6081 Estimated Time Left : 23.79 min(s)
# Progress : 3150/6081 Estimated Time Left : 24.68 min(s)
# Progress : 3160/6081 Estimated Time Left : 23.07 min(s)
# Progress : 3170/6081 Estimated Time Left : 29.09 min(s)
# Progress : 3180/6081 Estimated Time Left : 30.80 min(s)
# Progress : 3190/6081 Estimated Time Left : 24.98 min(s)
# Progress : 3200/6081 Estimated Time Left : 348.11 min(s)
# Progress : 3210/6081 Estimated Time Left : 35.26 min(s)
# Progress : 3220/6081 Estimated Time Left : 30.34 min(s)
# Progress : 3230/6081 Estimated Time Left : 32.52 min(s)
# Progress : 3240/6081 Estimated Time Left : 30.69 min(s)
# Progress : 3250/6081 Estimated Time Left : 32.95 min(s)
# Progress : 3260/6081 Estimated Time Left : 30.10 min(s)
# Progress : 3270/6081 Estimated Time Left : 30.44 min(s)
# Progress : 3280/6081 Estimated Time Left : 30.29 min(s)
# Progress : 3290/6081 Estimated Time Left : 31.13 min(s)
# Progress : 3300/6081 Estimated Time Left : 284.39 min(s)
# Progress : 3310/6081 Estimated Time Left : 25.89 min(s)
# Progress : 3320/6081 Estimated Time Left : 23.77 min(s)
# Progress : 3330/6081 Estimated Time Left : 27.21 min(s)
# Progress : 3340/6081 Estimated Time Left : 24.92 min(s)
# Progress : 3350/6081 Estimated Time Left : 25.00 min(s)
# Progress : 3360/6081 Estimated Time Left : 23.68 min(s)
# Progress : 3370/6081 Estimated Time Left : 26.26 min(s)
# Progress : 3380/6081 Estimated Time Left : 24.95 min(s)
# Progress : 3390/6081 Estimated Time Left : 28.53 min(s)
# Progress : 3400/6081 Estimated Time Left : 318.12 min(s)
# Progress : 3410/6081 Estimated Time Left : 26.00 min(s)
# Progress : 3420/6081 Estimated Time Left : 23.78 min(s)
# Progress : 3430/6081 Estimated Time Left : 22.17 min(s)
# Progress : 3440/6081 Estimated Time Left : 23.59 min(s)
# Progress : 3450/6081 Estimated Time Left : 25.12 min(s)
# Progress : 3460/6081 Estimated Time Left : 22.44 min(s)
# Progress : 3470/6081 Estimated Time Left : 22.98 min(s)
# Progress : 3480/6081 Estimated Time Left : 23.86 min(s)
# Progress : 3490/6081 Estimated Time Left : 22.96 min(s)
# Progress : 3500/6081 Estimated Time Left : 314.73 min(s)
# Progress : 3510/6081 Estimated Time Left : 26.31 min(s)
# Progress : 3520/6081 Estimated Time Left : 21.32 min(s)
# Progress : 3530/6081 Estimated Time Left : 24.15 min(s)
# Progress : 3540/6081 Estimated Time Left : 21.53 min(s)
# Progress : 3550/6081 Estimated Time Left : 26.44 min(s)
# Progress : 3560/6081 Estimated Time Left : 24.35 min(s)
# Progress : 3570/6081 Estimated Time Left : 22.93 min(s)
# Progress : 3580/6081 Estimated Time Left : 22.57 min(s)
# Progress : 3590/6081 Estimated Time Left : 23.74 min(s)
# Progress : 3600/6081 Estimated Time Left : 294.50 min(s)
# Progress : 3610/6081 Estimated Time Left : 20.30 min(s)
# Progress : 3620/6081 Estimated Time Left : 27.50 min(s)
# Progress : 3630/6081 Estimated Time Left : 23.11 min(s)
# Progress : 3640/6081 Estimated Time Left : 22.60 min(s)
# Progress : 3650/6081 Estimated Time Left : 23.91 min(s)
# Progress : 3660/6081 Estimated Time Left : 24.42 min(s)
# Progress : 3670/6081 Estimated Time Left : 27.61 min(s)
# Progress : 3680/6081 Estimated Time Left : 25.01 min(s)
# Progress : 3690/6081 Estimated Time Left : 21.79 min(s)
# Progress : 3700/6081 Estimated Time Left : 270.26 min(s)
# Progress : 3710/6081 Estimated Time Left : 30.68 min(s)
# Progress : 3720/6081 Estimated Time Left : 20.77 min(s)
# Progress : 3730/6081 Estimated Time Left : 20.69 min(s)
# Progress : 3740/6081 Estimated Time Left : 21.75 min(s)
# Progress : 3750/6081 Estimated Time Left : 22.92 min(s)
# Progress : 3760/6081 Estimated Time Left : 19.75 min(s)
# Progress : 3770/6081 Estimated Time Left : 24.08 min(s)
# Progress : 3780/6081 Estimated Time Left : 23.78 min(s)
# Progress : 3790/6081 Estimated Time Left : 21.61 min(s)
# Progress : 3800/6081 Estimated Time Left : 261.53 min(s)
# Progress : 3810/6081 Estimated Time Left : 19.69 min(s)
# Progress : 3820/6081 Estimated Time Left : 23.20 min(s)
# Progress : 3830/6081 Estimated Time Left : 20.56 min(s)
# Progress : 3840/6081 Estimated Time Left : 19.93 min(s)
# Progress : 3850/6081 Estimated Time Left : 20.45 min(s)
# Progress : 3860/6081 Estimated Time Left : 20.34 min(s)
# Progress : 3870/6081 Estimated Time Left : 20.88 min(s)
# Progress : 3880/6081 Estimated Time Left : 19.76 min(s)
# Progress : 3890/6081 Estimated Time Left : 21.36 min(s)
# Progress : 3900/6081 Estimated Time Left : 260.70 min(s)
# Progress : 3910/6081 Estimated Time Left : 21.70 min(s)
# Progress : 3920/6081 Estimated Time Left : 19.64 min(s)
# Progress : 3930/6081 Estimated Time Left : 19.72 min(s)
# Progress : 3940/6081 Estimated Time Left : 20.38 min(s)
# Progress : 3950/6081 Estimated Time Left : 19.66 min(s)
# Progress : 3960/6081 Estimated Time Left : 20.27 min(s)
# Progress : 3970/6081 Estimated Time Left : 20.41 min(s)
# Progress : 3980/6081 Estimated Time Left : 19.62 min(s)
# Progress : 3990/6081 Estimated Time Left : 18.76 min(s)
# Progress : 4000/6081 Estimated Time Left : 246.72 min(s)
# Progress : 4010/6081 Estimated Time Left : 19.66 min(s)
# Progress : 4020/6081 Estimated Time Left : 19.94 min(s)
# Progress : 4030/6081 Estimated Time Left : 16.65 min(s)
# Progress : 4040/6081 Estimated Time Left : 20.09 min(s)
# Progress : 4050/6081 Estimated Time Left : 18.43 min(s)
# Progress : 4060/6081 Estimated Time Left : 20.21 min(s)
# Progress : 4070/6081 Estimated Time Left : 20.39 min(s)
# Progress : 4080/6081 Estimated Time Left : 18.11 min(s)
# Progress : 4090/6081 Estimated Time Left : 20.99 min(s)
# Progress : 4100/6081 Estimated Time Left : 230.90 min(s)
# Progress : 4110/6081 Estimated Time Left : 18.83 min(s)
# Progress : 4120/6081 Estimated Time Left : 16.96 min(s)
# Progress : 4130/6081 Estimated Time Left : 17.14 min(s)
# Progress : 4140/6081 Estimated Time Left : 17.75 min(s)
# Progress : 4150/6081 Estimated Time Left : 16.78 min(s)
# Progress : 4160/6081 Estimated Time Left : 22.22 min(s)
# Progress : 4170/6081 Estimated Time Left : 18.66 min(s)
# Progress : 4180/6081 Estimated Time Left : 17.91 min(s)
# Progress : 4190/6081 Estimated Time Left : 16.64 min(s)
# Progress : 4200/6081 Estimated Time Left : 222.39 min(s)
# Progress : 4210/6081 Estimated Time Left : 23.65 min(s)
# Progress : 4220/6081 Estimated Time Left : 18.50 min(s)
# Progress : 4230/6081 Estimated Time Left : 20.63 min(s)
# Progress : 4240/6081 Estimated Time Left : 21.37 min(s)
# Progress : 4250/6081 Estimated Time Left : 16.94 min(s)
# Progress : 4260/6081 Estimated Time Left : 22.09 min(s)
# Progress : 4270/6081 Estimated Time Left : 20.90 min(s)
# Progress : 4280/6081 Estimated Time Left : 19.71 min(s)
# Progress : 4290/6081 Estimated Time Left : 23.28 min(s)
# Progress : 4300/6081 Estimated Time Left : 179.48 min(s)
# Progress : 4310/6081 Estimated Time Left : 14.59 min(s)
# Progress : 4320/6081 Estimated Time Left : 18.28 min(s)
# Progress : 4330/6081 Estimated Time Left : 14.07 min(s)
# Progress : 4340/6081 Estimated Time Left : 15.73 min(s)
# Progress : 4350/6081 Estimated Time Left : 17.68 min(s)
# Progress : 4360/6081 Estimated Time Left : 16.51 min(s)
# Progress : 4370/6081 Estimated Time Left : 14.98 min(s)
# Progress : 4380/6081 Estimated Time Left : 14.58 min(s)
# Progress : 4390/6081 Estimated Time Left : 15.64 min(s)
# Progress : 4400/6081 Estimated Time Left : 202.39 min(s)
# Progress : 4410/6081 Estimated Time Left : 14.06 min(s)
# Progress : 4420/6081 Estimated Time Left : 16.45 min(s)
# Progress : 4430/6081 Estimated Time Left : 15.74 min(s)
# Progress : 4440/6081 Estimated Time Left : 16.83 min(s)
# Progress : 4450/6081 Estimated Time Left : 14.84 min(s)
# Progress : 4460/6081 Estimated Time Left : 13.42 min(s)
# Progress : 4470/6081 Estimated Time Left : 14.95 min(s)
# Progress : 4480/6081 Estimated Time Left : 14.95 min(s)
# Progress : 4490/6081 Estimated Time Left : 17.27 min(s)
# Progress : 4500/6081 Estimated Time Left : 186.69 min(s)
# Progress : 4510/6081 Estimated Time Left : 15.31 min(s)
# Progress : 4520/6081 Estimated Time Left : 13.62 min(s)
# Progress : 4530/6081 Estimated Time Left : 14.02 min(s)
# Progress : 4540/6081 Estimated Time Left : 13.04 min(s)
# Progress : 4550/6081 Estimated Time Left : 21.69 min(s)
# Progress : 4560/6081 Estimated Time Left : 15.56 min(s)
# Progress : 4570/6081 Estimated Time Left : 14.75 min(s)
# Progress : 4580/6081 Estimated Time Left : 13.00 min(s)
# Progress : 4590/6081 Estimated Time Left : 14.08 min(s)
# Progress : 4600/6081 Estimated Time Left : 169.93 min(s)
# Progress : 4610/6081 Estimated Time Left : 14.13 min(s)
# Progress : 4620/6081 Estimated Time Left : 14.66 min(s)
# Progress : 4630/6081 Estimated Time Left : 12.71 min(s)
# Progress : 4640/6081 Estimated Time Left : 15.15 min(s)
# Progress : 4650/6081 Estimated Time Left : 13.03 min(s)
# Progress : 4660/6081 Estimated Time Left : 12.21 min(s)
# Progress : 4670/6081 Estimated Time Left : 14.92 min(s)
# Progress : 4680/6081 Estimated Time Left : 12.72 min(s)
# Progress : 4690/6081 Estimated Time Left : 13.82 min(s)
# Progress : 4700/6081 Estimated Time Left : 161.30 min(s)
# Progress : 4710/6081 Estimated Time Left : 12.34 min(s)
# Progress : 4720/6081 Estimated Time Left : 13.64 min(s)
# Progress : 4730/6081 Estimated Time Left : 11.90 min(s)
# Progress : 4740/6081 Estimated Time Left : 13.33 min(s)
# Progress : 4750/6081 Estimated Time Left : 12.69 min(s)
# Progress : 4760/6081 Estimated Time Left : 11.31 min(s)
# Progress : 4770/6081 Estimated Time Left : 10.37 min(s)
# Progress : 4780/6081 Estimated Time Left : 10.95 min(s)
# Progress : 4790/6081 Estimated Time Left : 11.64 min(s)
# Progress : 4800/6081 Estimated Time Left : 156.04 min(s)
# Progress : 4810/6081 Estimated Time Left : 12.40 min(s)
# Progress : 4820/6081 Estimated Time Left : 10.58 min(s)
# Progress : 4830/6081 Estimated Time Left : 12.93 min(s)
# Progress : 4840/6081 Estimated Time Left : 12.02 min(s)
# Progress : 4850/6081 Estimated Time Left : 9.96 min(s)
# Progress : 4860/6081 Estimated Time Left : 10.37 min(s)
# Progress : 4870/6081 Estimated Time Left : 11.12 min(s)
# Progress : 4880/6081 Estimated Time Left : 9.83 min(s)
# Progress : 4890/6081 Estimated Time Left : 10.43 min(s)
# Progress : 4900/6081 Estimated Time Left : 144.05 min(s)
# Progress : 4910/6081 Estimated Time Left : 12.94 min(s)
# Progress : 4920/6081 Estimated Time Left : 11.42 min(s)
# Progress : 4930/6081 Estimated Time Left : 9.99 min(s)
# Progress : 4940/6081 Estimated Time Left : 9.75 min(s)
# Progress : 4950/6081 Estimated Time Left : 11.15 min(s)
# Progress : 4960/6081 Estimated Time Left : 10.89 min(s)
# Progress : 4970/6081 Estimated Time Left : 10.20 min(s)
# Progress : 4980/6081 Estimated Time Left : 9.55 min(s)
# Progress : 4990/6081 Estimated Time Left : 10.27 min(s)
# Progress : 5000/6081 Estimated Time Left : 127.59 min(s)
# Progress : 5010/6081 Estimated Time Left : 9.21 min(s)
# Progress : 5020/6081 Estimated Time Left : 10.81 min(s)
# Progress : 5030/6081 Estimated Time Left : 9.48 min(s)
# Progress : 5040/6081 Estimated Time Left : 10.53 min(s)
# Progress : 5050/6081 Estimated Time Left : 10.66 min(s)
# Progress : 5060/6081 Estimated Time Left : 10.77 min(s)
# Progress : 5070/6081 Estimated Time Left : 9.98 min(s)
# Progress : 5080/6081 Estimated Time Left : 10.37 min(s)
# Progress : 5090/6081 Estimated Time Left : 10.64 min(s)
# Progress : 5100/6081 Estimated Time Left : 111.07 min(s)
# Progress : 5110/6081 Estimated Time Left : 8.95 min(s)
# Progress : 5120/6081 Estimated Time Left : 8.45 min(s)
# Progress : 5130/6081 Estimated Time Left : 8.54 min(s)
# Progress : 5140/6081 Estimated Time Left : 7.97 min(s)
# Progress : 5150/6081 Estimated Time Left : 9.04 min(s)
# Progress : 5160/6081 Estimated Time Left : 8.62 min(s)
# Progress : 5170/6081 Estimated Time Left : 7.41 min(s)
# Progress : 5180/6081 Estimated Time Left : 7.72 min(s)
# Progress : 5190/6081 Estimated Time Left : 7.88 min(s)
# Progress : 5200/6081 Estimated Time Left : 108.09 min(s)
# Progress : 5210/6081 Estimated Time Left : 7.77 min(s)
# Progress : 5220/6081 Estimated Time Left : 7.40 min(s)
# Progress : 5230/6081 Estimated Time Left : 7.43 min(s)
# Progress : 5240/6081 Estimated Time Left : 7.84 min(s)
# Progress : 5250/6081 Estimated Time Left : 7.74 min(s)
# Progress : 5260/6081 Estimated Time Left : 7.97 min(s)
# Progress : 5270/6081 Estimated Time Left : 6.90 min(s)
# Progress : 5280/6081 Estimated Time Left : 6.80 min(s)
# Progress : 5290/6081 Estimated Time Left : 6.15 min(s)
# Progress : 5300/6081 Estimated Time Left : 96.73 min(s)
# Progress : 5310/6081 Estimated Time Left : 7.63 min(s)
# Progress : 5320/6081 Estimated Time Left : 8.17 min(s)
# Progress : 5330/6081 Estimated Time Left : 6.67 min(s)
# Progress : 5340/6081 Estimated Time Left : 7.08 min(s)
# Progress : 5350/6081 Estimated Time Left : 6.23 min(s)
# Progress : 5360/6081 Estimated Time Left : 6.41 min(s)
# Progress : 5370/6081 Estimated Time Left : 7.41 min(s)
# Progress : 5380/6081 Estimated Time Left : 6.05 min(s)
# Progress : 5390/6081 Estimated Time Left : 6.08 min(s)
# Progress : 5400/6081 Estimated Time Left : 80.77 min(s)
# Progress : 5410/6081 Estimated Time Left : 5.66 min(s)
# Progress : 5420/6081 Estimated Time Left : 8.72 min(s)
# Progress : 5430/6081 Estimated Time Left : 5.98 min(s)
# Progress : 5440/6081 Estimated Time Left : 6.49 min(s)
# Progress : 5450/6081 Estimated Time Left : 5.90 min(s)
# Progress : 5460/6081 Estimated Time Left : 7.23 min(s)
# Progress : 5470/6081 Estimated Time Left : 6.22 min(s)
# Progress : 5480/6081 Estimated Time Left : 6.29 min(s)
# Progress : 5490/6081 Estimated Time Left : 6.26 min(s)
# Progress : 5500/6081 Estimated Time Left : 63.57 min(s)
# Progress : 5510/6081 Estimated Time Left : 5.06 min(s)
# Progress : 5520/6081 Estimated Time Left : 5.86 min(s)
# Progress : 5530/6081 Estimated Time Left : 5.30 min(s)
# Progress : 5540/6081 Estimated Time Left : 5.19 min(s)
# Progress : 5550/6081 Estimated Time Left : 4.67 min(s)
# Progress : 5560/6081 Estimated Time Left : 4.95 min(s)
# Progress : 5570/6081 Estimated Time Left : 4.46 min(s)
# Progress : 5580/6081 Estimated Time Left : 4.91 min(s)
# Progress : 5590/6081 Estimated Time Left : 4.09 min(s)
# Progress : 5600/6081 Estimated Time Left : 57.13 min(s)
# Progress : 5610/6081 Estimated Time Left : 4.08 min(s)
# Progress : 5620/6081 Estimated Time Left : 4.48 min(s)
# Progress : 5630/6081 Estimated Time Left : 5.17 min(s)
# Progress : 5640/6081 Estimated Time Left : 4.01 min(s)
# Progress : 5650/6081 Estimated Time Left : 3.99 min(s)
# Progress : 5660/6081 Estimated Time Left : 3.60 min(s)
# Progress : 5670/6081 Estimated Time Left : 4.25 min(s)
# Progress : 5680/6081 Estimated Time Left : 3.90 min(s)
# Progress : 5690/6081 Estimated Time Left : 3.54 min(s)
# Progress : 5700/6081 Estimated Time Left : 44.74 min(s)
# Progress : 5710/6081 Estimated Time Left : 5.57 min(s)
# Progress : 5720/6081 Estimated Time Left : 3.48 min(s)
# Progress : 5730/6081 Estimated Time Left : 4.28 min(s)
# Progress : 5740/6081 Estimated Time Left : 3.71 min(s)
# Progress : 5750/6081 Estimated Time Left : 3.29 min(s)
# Progress : 5760/6081 Estimated Time Left : 3.73 min(s)
# Progress : 5770/6081 Estimated Time Left : 3.18 min(s)
# Progress : 5780/6081 Estimated Time Left : 3.21 min(s)
# Progress : 5790/6081 Estimated Time Left : 3.15 min(s)
# Progress : 5800/6081 Estimated Time Left : 28.51 min(s)
# Progress : 5810/6081 Estimated Time Left : 2.47 min(s)
# Progress : 5820/6081 Estimated Time Left : 2.45 min(s)
# Progress : 5830/6081 Estimated Time Left : 2.41 min(s)
# Progress : 5840/6081 Estimated Time Left : 2.11 min(s)
# Progress : 5850/6081 Estimated Time Left : 2.25 min(s)
# Progress : 5860/6081 Estimated Time Left : 2.51 min(s)
# Progress : 5870/6081 Estimated Time Left : 1.97 min(s)
# Progress : 5880/6081 Estimated Time Left : 2.10 min(s)
# Progress : 5890/6081 Estimated Time Left : 1.73 min(s)
# Progress : 5900/6081 Estimated Time Left : 21.02 min(s)
# Progress : 5910/6081 Estimated Time Left : 1.42 min(s)
# Progress : 5920/6081 Estimated Time Left : 1.64 min(s)
# Progress : 5930/6081 Estimated Time Left : 1.32 min(s)
# Progress : 5940/6081 Estimated Time Left : 1.20 min(s)
# Progress : 5950/6081 Estimated Time Left : 1.19 min(s)
# Progress : 5960/6081 Estimated Time Left : 1.18 min(s)
# Progress : 5970/6081 Estimated Time Left : 1.09 min(s)
# Progress : 5980/6081 Estimated Time Left : 0.93 min(s)
# Progress : 5990/6081 Estimated Time Left : 0.90 min(s)
# Progress : 6000/6081 Estimated Time Left : 9.68 min(s)
# Progress : 6010/6081 Estimated Time Left : 0.68 min(s)
# Progress : 6020/6081 Estimated Time Left : 0.55 min(s)
# Progress : 6030/6081 Estimated Time Left : 0.44 min(s)
# Progress : 6040/6081 Estimated Time Left : 0.34 min(s)
# Progress : 6050/6081 Estimated Time Left : 0.29 min(s)
# Progress : 6060/6081 Estimated Time Left : 0.20 min(s)
# Progress : 6070/6081 Estimated Time Left : 0.10 min(s)
# Progress : 6080/6081 Estimated Time Left : 0.01 min(s)

# %%
# Check types of events occured in typical LoL matches

event_types = set()

for match in matches_timeline:
    for timestep in match['info']['frames']:
        for event in timestep['events']:
            event_types.add(event['type'])
            if event['type'] == 'BUILDING_KILL':
                x = match
            
event_types
# Out:
# {'BUILDING_KILL',
#  'CHAMPION_KILL',
#  'CHAMPION_SPECIAL_KILL',
#  'CHAMPION_TRANSFORM',
#  'DRAGON_SOUL_GIVEN',
#  'ELITE_MONSTER_KILL',
#  'GAME_END',
#  'ITEM_DESTROYED',
#  'ITEM_PURCHASED',
#  'ITEM_SOLD',
#  'ITEM_UNDO',
#  'LEVEL_UP',
#  'PAUSE_END',
#  'SKILL_LEVEL_UP',
#  'TURRET_PLATE_DESTROYED',
#  'WARD_KILL',
#  'WARD_PLACED'}

# %%
# Create .csv file with each team's stats at 10-min mark and whether the team proceeds to win or not
# For supervised learning -> Win prediction

data = pd.DataFrame()

for index, match in enumerate(matches_timeline):

    wards_placed = []
    wards_kill = []
    kills = []
    assists = []
    deaths = []

    dragon_kill = dict(red=0, blue=0)
    herald_kill = dict(red=0, blue=0)

    buildings_destroyed_blue = []
    buildings_destroyed_red = []


    # Retrieve every events in the match up until 10 minutes mark

    for timestamp in match['info']['frames'][:12]:
        for event in timestamp['events']:
            if event['type'] == 'WARD_PLACED' and event['wardType'] != 'UNDEFINED':
                wards_placed.append(event['creatorId'])
            elif event['type'] == 'WARD_KILL' and event['wardType'] != 'UNDEFINED':
                wards_kill.append(event['killerId'])
            elif event['type'] == 'CHAMPION_KILL':
                kills.append(event['killerId'])
                deaths.append(event['victimId'])
                try:
                    assists.extend(event['assistingParticipantIds'])
                except:
                    pass
            elif event['type'] == 'BUILDING_KILL':
                if event['teamId'] == 100:
                    buildings_destroyed_blue.append(event['buildingType'])
                else:
                    buildings_destroyed_red.append(event['buildingType'])

            elif event['type'] == 'ELITE_MONSTER_KILL':
                if event['monsterType'] == 'DRAGON':
                    if event['killerTeamId'] == 100:
                        dragon_kill['blue'] += 1
                    else:
                        dragon_kill['red'] += 1
                elif event['monsterType'] == 'RIFTHERALD':
                    if event['killerTeamId'] == 100:
                        herald_kill['blue'] += 1
                    else:
                        herald_kill['red'] += 1
                else:
                    see.append(event['monsterType'])
            else:
                pass


    # Get [total team gold, average team level,  total team exp, total cs] at 10 min marks

    total_gold = dict(red=0, blue=0)
    total_exp = dict(red=0, blue=0)
    total_cs = dict(red=0, blue=0)
    level = dict(red=[], blue=[])
    total_kills = dict(red=0, blue=0)
    total_assists = dict(red=0, blue=0)
    total_deaths = dict(red=0, blue=0)
    total_wards_placed = dict(red=0, blue=0)
    total_wards_kills = dict(red=0, blue=0)

    for player_id, info in match['info']['frames'][11]['participantFrames'].items():
        if int(player_id) <= 5:
            total_gold['blue'] += info['totalGold']
            total_exp['blue'] += info['xp']
            total_cs['blue'] += info['minionsKilled'] + info['jungleMinionsKilled']
            level['blue'].append(info['level'])
        else:
            total_gold['red'] += info['totalGold']
            total_exp['red'] += info['xp']
            total_cs['red'] += info['minionsKilled'] + info['jungleMinionsKilled']
            level['red'].append(info['level'])

    # Sum total team kills/assists/deaths

    for killer in kills:
        if killer <= 5:
            total_kills['blue'] += 1
        else:
            total_kills['red'] += 1

    for death_player in deaths:
        if death_player <= 5:
            total_deaths['blue'] += 1
        else:
            total_deaths['red'] += 1

    for assister in assists:
        if assister <= 5:
            total_assists['blue'] += 1
        else:
            total_assists['red'] += 1

    for ward_placer in wards_placed:
        if ward_placer <= 5:
            total_wards_placed['blue'] += 1
        else:
            total_wards_placed['red'] += 1

    for ward_killer in wards_kill:
        if ward_killer <= 5:
            total_wards_kills['blue'] += 1
        else:
            total_wards_kills['red'] += 1
    
    data = data.append(pd.DataFrame({'matchId': [match['metadata']['matchId']],
                                     'blue_wins': blue_wins.loc[match['metadata']['matchId']]['win'],
                                     'blue_kills': [total_kills['blue']],
                                     'blue_assists': [total_assists['blue']], 
                                     'blue_deaths': [total_deaths['blue']], 
                                     'blue_wards_placed': [total_wards_placed['blue']], 
                                     'blue_wards_kills': [total_wards_kills['blue']], 
                                     'blue_dragon_kills': [dragon_kill['blue']], 
                                     'blue_herald_kills': [herald_kill['blue']],
                                     'blue_tower_kills': [buildings_destroyed_red.count('TOWER_BUILDING')],
                                     'blue_inhibitor_kills': [buildings_destroyed_red.count('INHIBITOR_BUILDING')],
                                     'blue_total_gold': [total_gold['blue']],
                                     'blue_average_lvl': [np.mean(level['blue'])],
                                     'blue_total_exp': [total_exp['blue']],
                                     'blue_total_cs': [total_cs['blue']],
                                     'red_kills': [total_kills['red']],
                                     'red_assists': [total_assists['red']], 
                                     'red_deaths': [total_deaths['red']], 
                                     'red_wards_placed': [total_wards_placed['red']], 
                                     'red_wards_kills': [total_wards_kills['red']], 
                                     'red_dragon_kills': [dragon_kill['red']], 
                                     'red_herald_kills': [herald_kill['red']],
                                     'red_tower_kills': [buildings_destroyed_blue.count('TOWER_BUILDING')],
                                     'red_inhibitor_kills': [buildings_destroyed_blue.count('INHIBITOR_BUILDING')],
                                     'red_total_gold': [total_gold['red']],
                                     'red_average_lvl': [np.mean(level['red'])],
                                     'red_total_exp': [total_exp['red']],
                                     'red_total_cs': [total_cs['red']],
                                    }), ignore_index=True)
    
    if index%10==0:
        print(f'Progress : {index+1}/{len(matches_timeline)}')

data.to_csv('10mins_stats.csv', index=False)
# Out:
# Progress : 1/6081
# Progress : 11/6081
# Progress : 21/6081
# Progress : 31/6081
# Progress : 41/6081
# Progress : 51/6081
# Progress : 61/6081
# Progress : 71/6081
# Progress : 81/6081
# Progress : 91/6081
# Progress : 101/6081
# Progress : 111/6081
# Progress : 121/6081
# Progress : 131/6081
# Progress : 141/6081
# Progress : 151/6081
# Progress : 161/6081
# Progress : 171/6081
# Progress : 181/6081
# Progress : 191/6081
# Progress : 201/6081
# Progress : 211/6081
# Progress : 221/6081
# Progress : 231/6081
# Progress : 241/6081
# Progress : 251/6081
# Progress : 261/6081
# Progress : 271/6081
# Progress : 281/6081
# Progress : 291/6081
# Progress : 301/6081
# Progress : 311/6081
# Progress : 321/6081
# Progress : 331/6081
# Progress : 341/6081
# Progress : 351/6081
# Progress : 361/6081
# Progress : 371/6081
# Progress : 381/6081
# Progress : 391/6081
# Progress : 401/6081
# Progress : 411/6081
# Progress : 421/6081
# Progress : 431/6081
# Progress : 441/6081
# Progress : 451/6081
# Progress : 461/6081
# Progress : 471/6081
# Progress : 481/6081
# Progress : 491/6081
# Progress : 501/6081
# Progress : 511/6081
# Progress : 521/6081
# Progress : 531/6081
# Progress : 541/6081
# Progress : 551/6081
# Progress : 561/6081
# Progress : 571/6081
# Progress : 581/6081
# Progress : 591/6081
# Progress : 601/6081
# Progress : 611/6081
# Progress : 621/6081
# Progress : 631/6081
# Progress : 641/6081
# Progress : 651/6081
# Progress : 661/6081
# Progress : 671/6081
# Progress : 681/6081
# Progress : 691/6081
# Progress : 701/6081
# Progress : 711/6081
# Progress : 721/6081
# Progress : 731/6081
# Progress : 741/6081
# Progress : 751/6081
# Progress : 761/6081
# Progress : 771/6081
# Progress : 781/6081
# Progress : 791/6081
# Progress : 801/6081
# Progress : 811/6081
# Progress : 821/6081
# Progress : 831/6081
# Progress : 841/6081
# Progress : 851/6081
# Progress : 861/6081
# Progress : 871/6081
# Progress : 881/6081
# Progress : 891/6081
# Progress : 901/6081
# Progress : 911/6081
# Progress : 921/6081
# Progress : 931/6081
# Progress : 941/6081
# Progress : 951/6081
# Progress : 961/6081
# Progress : 971/6081
# Progress : 981/6081
# Progress : 991/6081
# Progress : 1001/6081
# Progress : 1011/6081
# Progress : 1021/6081
# Progress : 1031/6081
# Progress : 1041/6081
# Progress : 1051/6081
# Progress : 1061/6081
# Progress : 1071/6081
# Progress : 1081/6081
# Progress : 1091/6081
# Progress : 1101/6081
# Progress : 1111/6081
# Progress : 1121/6081
# Progress : 1131/6081
# Progress : 1141/6081
# Progress : 1151/6081
# Progress : 1161/6081
# Progress : 1171/6081
# Progress : 1181/6081
# Progress : 1191/6081
# Progress : 1201/6081
# Progress : 1211/6081
# Progress : 1221/6081
# Progress : 1231/6081
# Progress : 1241/6081
# Progress : 1251/6081
# Progress : 1261/6081
# Progress : 1271/6081
# Progress : 1281/6081
# Progress : 1291/6081
# Progress : 1301/6081
# Progress : 1311/6081
# Progress : 1321/6081
# Progress : 1331/6081
# Progress : 1341/6081
# Progress : 1351/6081
# Progress : 1361/6081
# Progress : 1371/6081
# Progress : 1381/6081
# Progress : 1391/6081
# Progress : 1401/6081
# Progress : 1411/6081
# Progress : 1421/6081
# Progress : 1431/6081
# Progress : 1441/6081
# Progress : 1451/6081
# Progress : 1461/6081
# Progress : 1471/6081
# Progress : 1481/6081
# Progress : 1491/6081
# Progress : 1501/6081
# Progress : 1511/6081
# Progress : 1521/6081
# Progress : 1531/6081
# Progress : 1541/6081
# Progress : 1551/6081
# Progress : 1561/6081
# Progress : 1571/6081
# Progress : 1581/6081
# Progress : 1591/6081
# Progress : 1601/6081
# Progress : 1611/6081
# Progress : 1621/6081
# Progress : 1631/6081
# Progress : 1641/6081
# Progress : 1651/6081
# Progress : 1661/6081
# Progress : 1671/6081
# Progress : 1681/6081
# Progress : 1691/6081
# Progress : 1701/6081
# Progress : 1711/6081
# Progress : 1721/6081
# Progress : 1731/6081
# Progress : 1741/6081
# Progress : 1751/6081
# Progress : 1761/6081
# Progress : 1771/6081
# Progress : 1781/6081
# Progress : 1791/6081
# Progress : 1801/6081
# Progress : 1811/6081
# Progress : 1821/6081
# Progress : 1831/6081
# Progress : 1841/6081
# Progress : 1851/6081
# Progress : 1861/6081
# Progress : 1871/6081
# Progress : 1881/6081
# Progress : 1891/6081
# Progress : 1901/6081
# Progress : 1911/6081
# Progress : 1921/6081
# Progress : 1931/6081
# Progress : 1941/6081
# Progress : 1951/6081
# Progress : 1961/6081
# Progress : 1971/6081
# Progress : 1981/6081
# Progress : 1991/6081
# Progress : 2001/6081
# Progress : 2011/6081
# Progress : 2021/6081
# Progress : 2031/6081
# Progress : 2041/6081
# Progress : 2051/6081
# Progress : 2061/6081
# Progress : 2071/6081
# Progress : 2081/6081
# Progress : 2091/6081
# Progress : 2101/6081
# Progress : 2111/6081
# Progress : 2121/6081
# Progress : 2131/6081
# Progress : 2141/6081
# Progress : 2151/6081
# Progress : 2161/6081
# Progress : 2171/6081
# Progress : 2181/6081
# Progress : 2191/6081
# Progress : 2201/6081
# Progress : 2211/6081
# Progress : 2221/6081
# Progress : 2231/6081
# Progress : 2241/6081
# Progress : 2251/6081
# Progress : 2261/6081
# Progress : 2271/6081
# Progress : 2281/6081
# Progress : 2291/6081
# Progress : 2301/6081
# Progress : 2311/6081
# Progress : 2321/6081
# Progress : 2331/6081
# Progress : 2341/6081
# Progress : 2351/6081
# Progress : 2361/6081
# Progress : 2371/6081
# Progress : 2381/6081
# Progress : 2391/6081
# Progress : 2401/6081
# Progress : 2411/6081
# Progress : 2421/6081
# Progress : 2431/6081
# Progress : 2441/6081
# Progress : 2451/6081
# Progress : 2461/6081
# Progress : 2471/6081
# Progress : 2481/6081
# Progress : 2491/6081
# Progress : 2501/6081
# Progress : 2511/6081
# Progress : 2521/6081
# Progress : 2531/6081
# Progress : 2541/6081
# Progress : 2551/6081
# Progress : 2561/6081
# Progress : 2571/6081
# Progress : 2581/6081
# Progress : 2591/6081
# Progress : 2601/6081
# Progress : 2611/6081
# Progress : 2621/6081
# Progress : 2631/6081
# Progress : 2641/6081
# Progress : 2651/6081
# Progress : 2661/6081
# Progress : 2671/6081
# Progress : 2681/6081
# Progress : 2691/6081
# Progress : 2701/6081
# Progress : 2711/6081
# Progress : 2721/6081
# Progress : 2731/6081
# Progress : 2741/6081
# Progress : 2751/6081
# Progress : 2761/6081
# Progress : 2771/6081
# Progress : 2781/6081
# Progress : 2791/6081
# Progress : 2801/6081
# Progress : 2811/6081
# Progress : 2821/6081
# Progress : 2831/6081
# Progress : 2841/6081
# Progress : 2851/6081
# Progress : 2861/6081
# Progress : 2871/6081
# Progress : 2881/6081
# Progress : 2891/6081
# Progress : 2901/6081
# Progress : 2911/6081
# Progress : 2921/6081
# Progress : 2931/6081
# Progress : 2941/6081
# Progress : 2951/6081
# Progress : 2961/6081
# Progress : 2971/6081
# Progress : 2981/6081
# Progress : 2991/6081
# Progress : 3001/6081
# Progress : 3011/6081
# Progress : 3021/6081
# Progress : 3031/6081
# Progress : 3041/6081
# Progress : 3051/6081
# Progress : 3061/6081
# Progress : 3071/6081
# Progress : 3081/6081
# Progress : 3091/6081
# Progress : 3101/6081
# Progress : 3111/6081
# Progress : 3121/6081
# Progress : 3131/6081
# Progress : 3141/6081
# Progress : 3151/6081
# Progress : 3161/6081
# Progress : 3171/6081
# Progress : 3181/6081
# Progress : 3191/6081
# Progress : 3201/6081
# Progress : 3211/6081
# Progress : 3221/6081
# Progress : 3231/6081
# Progress : 3241/6081
# Progress : 3251/6081
# Progress : 3261/6081
# Progress : 3271/6081
# Progress : 3281/6081
# Progress : 3291/6081
# Progress : 3301/6081
# Progress : 3311/6081
# Progress : 3321/6081
# Progress : 3331/6081
# Progress : 3341/6081
# Progress : 3351/6081
# Progress : 3361/6081
# Progress : 3371/6081
# Progress : 3381/6081
# Progress : 3391/6081
# Progress : 3401/6081
# Progress : 3411/6081
# Progress : 3421/6081
# Progress : 3431/6081
# Progress : 3441/6081
# Progress : 3451/6081
# Progress : 3461/6081
# Progress : 3471/6081
# Progress : 3481/6081
# Progress : 3491/6081
# Progress : 3501/6081
# Progress : 3511/6081
# Progress : 3521/6081
# Progress : 3531/6081
# Progress : 3541/6081
# Progress : 3551/6081
# Progress : 3561/6081
# Progress : 3571/6081
# Progress : 3581/6081
# Progress : 3591/6081
# Progress : 3601/6081
# Progress : 3611/6081
# Progress : 3621/6081
# Progress : 3631/6081
# Progress : 3641/6081
# Progress : 3651/6081
# Progress : 3661/6081
# Progress : 3671/6081
# Progress : 3681/6081
# Progress : 3691/6081
# Progress : 3701/6081
# Progress : 3711/6081
# Progress : 3721/6081
# Progress : 3731/6081
# Progress : 3741/6081
# Progress : 3751/6081
# Progress : 3761/6081
# Progress : 3771/6081
# Progress : 3781/6081
# Progress : 3791/6081
# Progress : 3801/6081
# Progress : 3811/6081
# Progress : 3821/6081
# Progress : 3831/6081
# Progress : 3841/6081
# Progress : 3851/6081
# Progress : 3861/6081
# Progress : 3871/6081
# Progress : 3881/6081
# Progress : 3891/6081
# Progress : 3901/6081
# Progress : 3911/6081
# Progress : 3921/6081
# Progress : 3931/6081
# Progress : 3941/6081
# Progress : 3951/6081
# Progress : 3961/6081
# Progress : 3971/6081
# Progress : 3981/6081
# Progress : 3991/6081
# Progress : 4001/6081
# Progress : 4011/6081
# Progress : 4021/6081
# Progress : 4031/6081
# Progress : 4041/6081
# Progress : 4051/6081
# Progress : 4061/6081
# Progress : 4071/6081
# Progress : 4081/6081
# Progress : 4091/6081
# Progress : 4101/6081
# Progress : 4111/6081
# Progress : 4121/6081
# Progress : 4131/6081
# Progress : 4141/6081
# Progress : 4151/6081
# Progress : 4161/6081
# Progress : 4171/6081
# Progress : 4181/6081
# Progress : 4191/6081
# Progress : 4201/6081
# Progress : 4211/6081
# Progress : 4221/6081
# Progress : 4231/6081
# Progress : 4241/6081
# Progress : 4251/6081
# Progress : 4261/6081
# Progress : 4271/6081
# Progress : 4281/6081
# Progress : 4291/6081
# Progress : 4301/6081
# Progress : 4311/6081
# Progress : 4321/6081
# Progress : 4331/6081
# Progress : 4341/6081
# Progress : 4351/6081
# Progress : 4361/6081
# Progress : 4371/6081
# Progress : 4381/6081
# Progress : 4391/6081
# Progress : 4401/6081
# Progress : 4411/6081
# Progress : 4421/6081
# Progress : 4431/6081
# Progress : 4441/6081
# Progress : 4451/6081
# Progress : 4461/6081
# Progress : 4471/6081
# Progress : 4481/6081
# Progress : 4491/6081
# Progress : 4501/6081
# Progress : 4511/6081
# Progress : 4521/6081
# Progress : 4531/6081
# Progress : 4541/6081
# Progress : 4551/6081
# Progress : 4561/6081
# Progress : 4571/6081
# Progress : 4581/6081
# Progress : 4591/6081
# Progress : 4601/6081
# Progress : 4611/6081
# Progress : 4621/6081
# Progress : 4631/6081
# Progress : 4641/6081
# Progress : 4651/6081
# Progress : 4661/6081
# Progress : 4671/6081
# Progress : 4681/6081
# Progress : 4691/6081
# Progress : 4701/6081
# Progress : 4711/6081
# Progress : 4721/6081
# Progress : 4731/6081
# Progress : 4741/6081
# Progress : 4751/6081
# Progress : 4761/6081
# Progress : 4771/6081
# Progress : 4781/6081
# Progress : 4791/6081
# Progress : 4801/6081
# Progress : 4811/6081
# Progress : 4821/6081
# Progress : 4831/6081
# Progress : 4841/6081
# Progress : 4851/6081
# Progress : 4861/6081
# Progress : 4871/6081
# Progress : 4881/6081
# Progress : 4891/6081
# Progress : 4901/6081
# Progress : 4911/6081
# Progress : 4921/6081
# Progress : 4931/6081
# Progress : 4941/6081
# Progress : 4951/6081
# Progress : 4961/6081
# Progress : 4971/6081
# Progress : 4981/6081
# Progress : 4991/6081
# Progress : 5001/6081
# Progress : 5011/6081
# Progress : 5021/6081
# Progress : 5031/6081
# Progress : 5041/6081
# Progress : 5051/6081
# Progress : 5061/6081
# Progress : 5071/6081
# Progress : 5081/6081
# Progress : 5091/6081
# Progress : 5101/6081
# Progress : 5111/6081
# Progress : 5121/6081
# Progress : 5131/6081
# Progress : 5141/6081
# Progress : 5151/6081
# Progress : 5161/6081
# Progress : 5171/6081
# Progress : 5181/6081
# Progress : 5191/6081
# Progress : 5201/6081
# Progress : 5211/6081
# Progress : 5221/6081
# Progress : 5231/6081
# Progress : 5241/6081
# Progress : 5251/6081
# Progress : 5261/6081
# Progress : 5271/6081
# Progress : 5281/6081
# Progress : 5291/6081
# Progress : 5301/6081
# Progress : 5311/6081
# Progress : 5321/6081
# Progress : 5331/6081
# Progress : 5341/6081
# Progress : 5351/6081
# Progress : 5361/6081
# Progress : 5371/6081
# Progress : 5381/6081
# Progress : 5391/6081
# Progress : 5401/6081
# Progress : 5411/6081
# Progress : 5421/6081
# Progress : 5431/6081
# Progress : 5441/6081
# Progress : 5451/6081
# Progress : 5461/6081
# Progress : 5471/6081
# Progress : 5481/6081
# Progress : 5491/6081
# Progress : 5501/6081
# Progress : 5511/6081
# Progress : 5521/6081
# Progress : 5531/6081
# Progress : 5541/6081
# Progress : 5551/6081
# Progress : 5561/6081
# Progress : 5571/6081
# Progress : 5581/6081
# Progress : 5591/6081
# Progress : 5601/6081
# Progress : 5611/6081
# Progress : 5621/6081
# Progress : 5631/6081
# Progress : 5641/6081
# Progress : 5651/6081
# Progress : 5661/6081
# Progress : 5671/6081
# Progress : 5681/6081
# Progress : 5691/6081
# Progress : 5701/6081
# Progress : 5711/6081
# Progress : 5721/6081
# Progress : 5731/6081
# Progress : 5741/6081
# Progress : 5751/6081
# Progress : 5761/6081
# Progress : 5771/6081
# Progress : 5781/6081
# Progress : 5791/6081
# Progress : 5801/6081
# Progress : 5811/6081
# Progress : 5821/6081
# Progress : 5831/6081
# Progress : 5841/6081
# Progress : 5851/6081
# Progress : 5861/6081
# Progress : 5871/6081
# Progress : 5881/6081
# Progress : 5891/6081
# Progress : 5901/6081
# Progress : 5911/6081
# Progress : 5921/6081
# Progress : 5931/6081
# Progress : 5941/6081
# Progress : 5951/6081
# Progress : 5961/6081
# Progress : 5971/6081
# Progress : 5981/6081
# Progress : 5991/6081
# Progress : 6001/6081
# Progress : 6011/6081
# Progress : 6021/6081
# Progress : 6031/6081
# Progress : 6041/6081
# Progress : 6051/6081
# Progress : 6061/6081
# Progress : 6071/6081
# Progress : 6081/6081
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-592-0367cf3ef6a9> in <module>
#     146         print(f'Progress : {index+1}/{len(matches_timeline)}')
#     147
# --> 148 data.to_csv('10mins_stats.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: '10mins_stats.csv'
